# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("group_data.csv")

# %%
data.head(20)
# Out:
#     Unnamed: 0 opdb_id  is_machine_group              name shortname  \
# 0            0   G5pe4              True  Medieval Madness        MM
# 1            1   G4do5              True  Attack from Mars       AFM
# 2            2   GrEZ5              True         El Dorado       NaN
# 3            3   GRoz4              True         Batman 66       B66
# 4            4   G41d5              True   Game of Thrones       GOT
# 5            5   G5WBr              True  The Big Lebowski       TBL
# 6            6   G5nz5              True  The Walking Dead       TWD
# 7            7   G4jXr              True              KISS      KISS
# 8            8   G4qX5              True              KISS      KISS
# 9            9   GR9Nr              True      Ghostbusters        GB
# 10          10   Gryw4              True         Star Trek        ST
# 11          11   GrPOR              True           Mustang       NaN
# 12          12   GRVq4              True          Iron Man        IM
# ...

# %%
data = data.drop('Unnamed: 0', axis = 1)

# %%
set((data['opdb_id']).apply(len))
# Out:
# {5}

# %%
data = data.rename(columns = {"name":"group_name", "shortname": "group_shortname"})

# %%
data.head(30)
# Out:
#    opdb_id  is_machine_group             group_name group_shortname  \
# 0    G5pe4              True       Medieval Madness              MM
# 1    G4do5              True       Attack from Mars             AFM
# 2    GrEZ5              True              El Dorado             NaN
# 3    GRoz4              True              Batman 66             B66
# 4    G41d5              True        Game of Thrones             GOT
# 5    G5WBr              True       The Big Lebowski             TBL
# 6    G5nz5              True       The Walking Dead             TWD
# 7    G4jXr              True                   KISS            KISS
# 8    G4qX5              True                   KISS            KISS
# 9    GR9Nr              True           Ghostbusters              GB
# 10   Gryw4              True              Star Trek              ST
# 11   GrPOR              True                Mustang             NaN
# 12   GRVq4              True               Iron Man              IM
# ...

# %%
data.shape
# Out:
# (1549, 7)

# %%
data.to_csv("cln_group.csv")
